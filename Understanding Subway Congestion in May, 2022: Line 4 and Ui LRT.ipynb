# %% [markdown]
# <a href="https://colab.research.google.com/github/HyesunY/BasicPython/blob/main/SubwayData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 5월 승하차 데이터 불러오기

# %%
import numpy as np
import seaborn as sns
import pandas as pd


subwaya = pd.read_csv("E:/subwayon.csv",encoding='cp949')
subwayb = pd.read_csv("E:/subwayoff.csv",encoding='cp949')
subwaya5 = subwaya[subwaya['사용월'] == 202205]
subwaya5 = subwaya5.drop(columns={'사용월'})
subwaya5_line=subwaya5.groupby(['호선명','지하철역']).mean().reset_index()
subwaya5_time=subwaya5.groupby(['호선명']).mean().reset_index()
subwaya5_all=subwaya5.groupby(['지하철역']).mean().reset_index()

subwayb5 = subwayb[subwayb['사용월'] == 202205]
subwayb5 = subwayb5.drop(columns={'사용월'})
subwayb5_line=subwayb5.groupby(['호선명','지하철역']).mean().reset_index()
subwayb5_time=subwayb5.groupby(['호선명']).mean().reset_index()
subwayb5_all=subwayb5.groupby(['지하철역']).mean().reset_index()

subwaya5_suyu=subwaya5.query("지하철역=='수유(강북구청)'")
subwayb5_suyu=subwayb5.query("지하철역=='수유(강북구청)'")
subwaya5_419=subwaya5.query("지하철역=='4.19민주묘지'")
subwayb5_419=subwayb5.query("지하철역=='4.19민주묘지'")

subwaya5_ui = subwaya5_line[subwaya5_line['호선명']== '우이신설선']
subwayb5_line4 = subwayb5_line[subwayb5_line['호선명'] == '4호선']
subwayb5_ui = subwayb5_line[subwayb5_line['호선명']== '우이신설선']
subwaya5_line4 = subwaya5_line[subwaya5_line['호선명'] == '4호선']

# %%
alldata=pd.read_csv("C:/Users/hyeee/Desktop/all.csv",encoding='cp949')
alldata
# Out:
#          호선명      04시-05시        05시-06시         06시-07       07시-08시  \
# 0        1호선  5360.654312  117780.441700  251229.924500  611444.40520
# 1        2호선  4967.654312  111626.841700  243854.624500  594972.50520
# 2        3호선  4684.614312  101895.041700  226193.544500  550298.10520
# 3        4호선  4616.261371   97363.600510  215424.573900  522923.66400
# 4        5호선  4457.492140   89604.369750  198115.035400  481488.27940
# 5        6호선  4433.688568   84696.226890  186807.624700  450118.29720
# 6        7호선  4380.329594   80105.432020  178112.804200  427490.27160
# 7        8호선  4329.287041   73539.963930  165324.953100  395247.16520
# 8        9호선  4309.009263   68461.741710  154671.730900  367694.44300
# 9   9호선2~3단계  4275.769263   64096.981710  145441.490900  342103.44300
# 10       경강선  4268.076955   62236.597090  139992.952500  328071.28910
# 11       경부선  4263.531501   61103.324370  135838.497900  317302.74370
# ...

# %% [markdown]
# # 5월 전체지하철

# %%
import matplotlib.pyplot as plt

import plotly.graph_objects as go

sns.set(rc = {'figure.figsize':(20,10)})
plt.rcParams['font.family'] = 'Malgun Gothic'

fig, ax = plt.subplots()
ax.set_title('전체지하철 시간대별 평균 승차 인원', size = 22)
ax.tick_params(axis='x', labelsize = 8, labelrotation = 30)
sns.scatterplot(data=ex[3:17], s=200)
plt.legend(loc='right')

# %%
# 지하철 승하차 인원
subway5_time=pd.merge(subwaya5_time,subwayb5_time,how='outer',left_index=True, right_index=True)
subway5_time
# Out:
#        호선명_x  04시-05시 승차인원  05시-06시 승차인원  06시-07시 승차인원  07시-08시 승차인원  \
# 0        1호선    393.000000   6153.600000   7375.300000  16471.900000
# 1        2호선    283.040000   9731.800000  17661.080000  44674.400000
# 2        3호선     68.352941   4531.441176  10768.970588  27374.441176
# 3        4호선    158.769231   7759.230769  17309.538462  41435.384615
# 4        5호선     23.803571   4908.142857  11307.410714  31369.982143
# 5        6호선     53.358974   4590.794872   8694.820513  22628.025641
# 6        7호선     51.042553   6565.468085  12787.851064  32243.106383
# 7        8호선     20.277778   5078.222222  10653.222222  27552.722222
# 8        9호선     33.240000   4364.760000   9230.240000  25591.000000
# 9   9호선2~3단계      7.692308   1860.384615   5448.538462  14032.153846
# 10       경강선      4.545455   1133.272727   4154.454545  10768.545455
# 11       경부선    915.743590   7167.153846  12898.717949  29273.000000
# 12       경원선    634.100000   5249.366667   9320.633333  20694.133333
# ...

# %%
# 역별 지하철 승하차 인원
metro_recent
# Out:
#          사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 3690  202205  1호선  동대문           906            25         11875
# 3691  202205  1호선  동묘앞           173             3          2992
# 3692  202205  1호선  서울역           627            18          9072
# 3693  202205  1호선   시청           114             1          1976
# 3694  202205  1호선  신설동           381            16          8741
# ...      ...  ...  ...           ...           ...           ...
# 4300  202205  중앙선   원덕            85             1           431
# 4301  202205  중앙선   중랑           166             2          6660
# 4302  202205  중앙선   지평             0             0             1
# 4303  202205  중앙선   팔당             0             0           313
# 4304  202205  중앙선   회기           862            14         13527
#
#       05시-06시 하차인원  06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  \
# 3690          2131          9472          7920         15023  ...
# ...

# %%
metro_line=metro_recent.groupby(['호선명']).mean().reset_index()
metro_line=metro_line.drop(columns='사용월').set_index('호선명')
metro_line=metro_line.mean(axis=1).sort_values(ascending=False)
metro_line
# Out:
# 호선명
# 2호선         33286.942917
# 1호선         27651.906250
# 4호선         23160.770833
# 3호선         18760.615809
# 경인선         17463.229167
# 과천선         16563.645833
# 7호선         15335.682624
# 경부선         14825.416667
# 5호선         13763.715402
# 9호선         13433.932500
# 분당선         13135.075595
# 8호선         12598.212963
# 일산선         12110.034091
# 안산선         12005.278846
# 6호선         10445.220085
# 공항철도 1호선     8967.113095
# 9호선2~3단계     8894.312500
# 경원선          8522.933333
# 중앙선          5673.040675
# 경의선          5205.675154
# 수인선          4332.398148
# 우이신설선        4307.876603
# 경강선          3570.632576
# 장항선          3160.988095
# 경춘선          2748.345395
# 신림선           534.833333
# dtype: float64

# %%
metro_recent.groupby(['호선명']).mean()
# Out:
#                사용월  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  05시-06시 하차인원  \
# 호선명
# 1호선       202205.0    393.000000      9.700000   6153.600000   3709.400000
# 2호선       202205.0    283.040000      6.240000   9731.800000   2748.180000
# 3호선       202205.0     68.352941      3.352941   4531.441176   1187.558824
# 4호선       202205.0    158.769231      6.846154   7759.230769   1386.230769
# 5호선       202205.0     23.803571      0.250000   4908.142857    986.142857
# 6호선       202205.0     53.358974      0.846154   4590.794872    939.000000
# 7호선       202205.0     51.042553      0.553191   6565.468085   1443.212766
# 8호선       202205.0     20.277778      0.333333   5078.222222   1487.333333
# 9호선       202205.0     33.240000      0.400000   4364.760000   1045.960000
# 9호선2~3단계  202205.0      7.692308      0.461538   1860.384615    618.769231
# 경강선       202205.0      4.545455      0.090909   1133.272727     91.545455
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
fig, ax = plt.subplots()
plt.title('2022년 5월 호선별 이용객수', fontsize=30)
g=metro_line.plot(kind=('bar'))
ax=g
for p in ax.patches:
    ax.annotate("%.2f" % p.get_height(), (p.get_x() + p.get_width()/2., p.get_height() - 30),
       ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
       textcoords='offset points')
plt.show()

# %%
ex=pd.merge(subwaya5_time, subwayb5_time, how='outer',left_index=True, right_index=True)

ex.to_excel("E:/ex.xlsx")

# %%
alldata.style.background_gradient()\
                    .to_html("E:/alldata.html")

# %% [markdown]
# # 서울 지하철 1-9호선

# %% [markdown]
# ## 승차 인원

# %%
subwayb5_all=subwayb5.groupby(['지하철역']).mean().reset_index()
subwayb5_time
# Out:
#          호선명  04시-05시 하차인원  05시-06시 하차인원  06시-07시 하차인원  07시-08시 하차인원  \
# 0        1호선      9.700000   3709.400000  18722.300000  42813.100000
# 1        2호선      6.240000   2748.180000  16065.220000  39458.280000
# 2        3호선      3.352941   1187.558824  11145.264706  25571.735294
# 3        4호선      6.846154   1386.230769  11231.038462  24342.961538
# 4        5호선      0.250000    986.142857   6656.196429  17214.160714
# 5        6호선      0.846154    939.000000   4452.461538  10107.179487
# 6        7호선      0.553191   1443.212766   7471.255319  17189.553191
# 7        8호선      0.333333   1487.333333   6795.611111  13983.722222
# 8        9호선      0.400000   1045.960000   7266.360000  19621.640000
# 9   9호선2~3단계      0.461538    618.769231   4427.538462  10645.153846
# 10       경강선      0.090909     91.545455   1800.454545   5130.636364
# 11       경부선      9.153846   2466.051282   8844.307692  20693.794872
# 12       경원선      7.633333   1197.433333   4039.933333   6839.166667
# ...

# %%
subwaya5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 615 entries, 0 to 614
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   호선명           615 non-null    object
#  1   지하철역          615 non-null    object
#  2   04시-05시 승차인원  615 non-null    int64
#  3   05시-06시 승차인원  615 non-null    int64
#  4   06시-07시 승차인원  615 non-null    int64
#  5   07시-08시 승차인원  615 non-null    int64
#  6   08시-09시 승차인원  615 non-null    int64
#  7   09시-10시 승차인원  615 non-null    int64
#  8   10시-11시 승차인원  615 non-null    int64
#  9   11시-12시 승차인원  615 non-null    int64
#  10  12시-13시 승차인원  615 non-null    int64
#  11  13시-14시 승차인원  615 non-null    int64
#  12  14시-15시 승차인원  615 non-null    int64
#  13  15시-16시 승차인원  615 non-null    int64
#  14  16시-17시 승차인원  615 non-null    int64
#  15  17시-18시 승차인원  615 non-null    int64
#  16  18시-19시 승차인원  615 non-null    int64
#  17  19시-20시 승차인원  615 non-null    int64
# ...

# %%
subwaya5_group=subwaya5.groupby(['호선명','지하철역']).sum()
subwaya5_group.loc['4호선'].style.background_gradient()
plt.savefig('line4geton.png')
plt.show()

# %% [markdown]
# ## 하차 인원

# %%
subwayb5_time=subwayb5_time.loc[[0, 1, 2, 3,4,5,6,7,8]]
subwayb5_time
# Out:
#    호선명  04시-05시 하차인원  05시-06시 하차인원  06시-07시 하차인원  07시-08시 하차인원  08시-09시 하차인원  \
# 0  1호선      9.700000   3709.400000  18722.300000  42813.100000  98730.700000
# 1  2호선      6.240000   2748.180000  16065.220000  39458.280000  99040.580000
# 2  3호선      3.352941   1187.558824  11145.264706  25571.735294  51365.911765
# 3  4호선      6.846154   1386.230769  11231.038462  24342.961538  54474.115385
# 4  5호선      0.250000    986.142857   6656.196429  17214.160714  39813.232143
# 5  6호선      0.846154    939.000000   4452.461538  10107.179487  23743.820513
# 6  7호선      0.553191   1443.212766   7471.255319  17189.553191  43449.595745
# 7  8호선      0.333333   1487.333333   6795.611111  13983.722222  34773.611111
# 8  9호선      0.400000   1045.960000   7266.360000  19621.640000  38906.520000
#
#    09시-10시 하차인원  10시-11시 하차인원  11시-12시 하차인원  12시-13시 하차인원  ...  18시-19시 하차인원  \
# 0  62867.800000  43972.100000  45175.700000  44350.600000  ...  37008.500000
# ...

# %%
metro_get_on=pd.DataFrame()
metro_get_on['지하철역']=metro_st_line2['지하철역']
for i in range(int((len(metro_recent.columns)-3)/2)):
    metro_get_on[metro_st_line2.columns[3+2*i]]=metro_st_line2[metro_st_line2.columns[3+2*i]]
metro_get_on=metro_get_on.set_index('지하철역')

metro_get_off=pd.DataFrame()
metro_get_off['지하철역']=metro_st_line2['지하철역']
for i in range(int((len(metro_recent.columns)-3)/2)):
    metro_get_off[metro_st_line2.columns[4+2*i]]=metro_st_line2[metro_st_line2.columns[4+2*i]]
metro_get_off=metro_get_off.set_index('지하철역')
metro_get_off

df=pd.DataFrame(index=metro_st_line2['지하철역'])
df['평균 승차 인원 수']=metro_get_on.mean(axis=1).astype(int)
df['평균 하차 인원 수']=metro_get_off.mean(axis=1).astype(int)

# %% [markdown]
# # 4호선

# %%
subwayb5_line4 = subwayb5_line[subwayb5_line['호선명'] == '4호선']
subwayb5_line4
# Out:
#      호선명            지하철역  04시-05시 하차인원  05시-06시 하차인원  06시-07시 하차인원  \
# 94   4호선              길음           2.0        2462.0        7778.0
# 95   4호선             남태령           0.0         109.0        1402.0
# 96   4호선              노원           5.0         544.0        7700.0
# 97   4호선             당고개           0.0          56.0        5167.0
# 98   4호선             동대문          15.0        2602.0       16278.0
# 99   4호선  동대문역사문화공원(DDP)           1.0        1513.0       13394.0
# 100  4호선         동작(현충원)           0.0         270.0        2056.0
# 101  4호선              명동           1.0         968.0       18740.0
# 102  4호선     미아(서울사이버대학)           6.0        1512.0        5897.0
# 103  4호선           미아사거리           2.0        2406.0        8723.0
# 104  4호선              사당          63.0        1629.0       18702.0
# 105  4호선             삼각지           0.0         496.0        6997.0
# 106  4호선              상계           2.0         220.0        8190.0
# ...

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
fig, ax = plt.subplots()
sns.set(rc = {'figure.figsize':(20,10)})

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 15})

top10_on=df.sort_values(by='평균 승차 인원 수',ascending=False).head(10)
plt.bar(top10_on.index,top10_on['평균 승차 인원 수'], color ='teal')

for x,y in enumerate(list(top10_on['평균 승차 인원 수'])):
    if x==0:
        plt.annotate(y,(x-0.15,y),color='red')
    else:
        plt.annotate(y,(x-0.15,y))
plt.title('2022년 5월 4호선 평균 승차 인원 수 Top10', fontsize=30)
ax.tick_params(axis='x', labelsize = 15, labelrotation = 30)

plt.show()

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
fig, ax = plt.subplots()
sns.set(rc = {'figure.figsize':(20,10)})

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 15})

top10_off=df.sort_values(by='평균 승차 인원 수',ascending=False).head(10)

plt.bar(top10_off.index,top10_off['평균 하차 인원 수'], color ='teal')
for x,y in enumerate(list(top10_off['평균 하차 인원 수'])):
    if x==0:
        plt.annotate(y,(x-0.15,y),color='red')
    else:
        plt.annotate(y,(x-0.15,y))
plt.title('2022년 5월 4호선 평균 하차 인원 수 Top10', fontsize=30)
ax.tick_params(axis='x', labelsize = 15, labelrotation = 30)
plt.show()

# %%
df4=pd.read_csv("C:/Users/hyeee/Desktop/df4.csv",encoding='cp949')
df4
# Out:
#          시간  평균 승차 인원 수  평균 하차 인원 수
# 0   04시-05시         158           6
# 1   05시-06시        7759        1386
# 2   06시-07시       17309       11231
# 3   07시-08시       41435       24342
# 4   08시-09시       44909       54474
# 5   09시-10시       30531       38798
# 6   10시-11시       24304       29155
# 7   11시-12시       24900       28323
# 8   12시-13시       27592       29060
# 9   13시-14시       28250       30196
# 10  14시-15시       29305       29495
# 11  15시-16시       32878       30279
# 12  16시-17시       38605       33228
# 13  17시-18시       46408       40428
# 14  18시-19시       54398       53309
# 15  19시-20시       28952       42175
# 16  20시-21시       24467       25161
# 17  21시-22시       23144       22400
# 18  22시-23시       19605       20443
# 19  23시-24시        7180       14379
# 20  00시-01시          20        1319
# 21  01시-02시           0           0
# 22  02시-03시           0           0
# 23  03시-04시           0           0

# %%
metro_all=pd.read_csv("C:/Users/hyeee/Desktop/pydata/subwaydata.csv"
,encoding='cp949')
metro_all.head()
metro_all.info()
metro_recent=metro_all[metro_all['사용월']==202205]
metro_recent
metro_recent=metro_recent.drop(columns={'작업일자'})
metro_recent
metro_st=metro_recent.groupby(['호선명','지하철역']).mean().reset_index()
metro_st_line2=metro_st[metro_st['호선명']=='4호선']
metro_st_line2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55726 entries, 0 to 55725
# Data columns (total 52 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   사용월           55726 non-null  int64
#  1   호선명           55726 non-null  object
#  2   지하철역          55726 non-null  object
#  3   04시-05시 승차인원  55726 non-null  int64
#  4   04시-05시 하차인원  55726 non-null  int64
#  5   05시-06시 승차인원  55726 non-null  int64
#  6   05시-06시 하차인원  55726 non-null  int64
#  7   06시-07시 승차인원  55726 non-null  int64
#  8   06시-07시 하차인원  55726 non-null  int64
#  9   07시-08시 승차인원  55726 non-null  int64
#  10  07시-08시 하차인원  55726 non-null  int64
#  11  08시-09시 승차인원  55726 non-null  int64
#  12  08시-09시 하차인원  55726 non-null  int64
#  13  09시-10시 승차인원  55726 non-null  int64
#  14  09시-10시 하차인원  55726 non-null  int64
#  15  10시-11시 승차인원  55726 non-null  int64
#  16  10시-11시 하차인원  55726 non-null  int64
#  17  11시-12시 승차인원  55726 non-null  int64
# ...

# %%
ddf2=pd.read_table("C:/Users/hyeee/Documents/카카오톡 받은 파일/ddf2.txt")

plt.rc('font', family='Malgun Gothic')
matplotlib.rcParams['axes.unicode_minus'] =False
fig, ax = plt.subplots()
sns.set(rc = {'figure.figsize':(20,10)})

plt.plot(ddf2['지하철역'], ddf2['평균 승차 인원 수'], label='on')
plt.plot(ddf2['지하철역'], ddf2['평균 하차 인원 수'], label = 'off')

plt.title('2022년 5월 4호선 평균 승하차 인원 수', fontsize=30)
ax.tick_params(axis='x', labelsize = 15, labelrotation = 75)
ax.legend(fontsize=20)

# %%
plt.rc('font', family='Malgun Gothic')
matplotlib.rcParams['axes.unicode_minus'] =False
fig, ax = plt.subplots()
sns.set(rc = {'figure.figsize':(20,10)})

plt.plot(df4['시간'], df4['평균 승차 인원 수'], label='on')
plt.plot(df4['시간'], df4['평균 하차 인원 수'], label = 'off')

plt.title('2022년 5월 4호선 시간대별 평균 승하차 인원 수', fontsize=30)
ax.tick_params(axis='x', labelsize = 15, labelrotation = 75)
ax.legend(fontsize=20)

# %% [markdown]
# # 우이신설선

# %%
dfu=pd.read_csv("C:/Users/hyeee/Desktop/dfu.csv",encoding='cp949')
dfu
# Out:
#          시간  평균 승차 인원 수  평균 하차 인원 수
# 0   04시-05시          13           1
# 1   05시-06시        1794         445
# 2   06시-07시        4363        1700
# 3   07시-08시       11475        3396
# 4   08시-09시       13038        6883
# 5   09시-10시        8395        5180
# 6   10시-11시        6358        4910
# 7   11시-12시        5969        4773
# 8   12시-13시        6278        4886
# 9   13시-14시        6203        5215
# 10  14시-15시        5756        5239
# 11  15시-16시        5887        5870
# 12  16시-17시        6537        6826
# 13  17시-18시        6412        7897
# 14  18시-19시        6115       10552
# 15  19시-20시        3750        9083
# 16  20시-21시        2776        5569
# 17  21시-22시        2446        4995
# 18  22시-23시        1743        4420
# 19  23시-24시         692        2823
# 20  00시-01시           8          89
# 21  01시-02시           0           0
# 22  02시-03시           0           0
# 23  03시-04시           0           0

# %%
uion=pd.read_table("E:우이승차.txt")
uion
# Out:
#           지하철역         승차인원
# 0     4.19민주묘지  4531.458333
# 1          가오리  5208.750000
# 2           보문  1948.125000
# 3       북한산보국문  7886.666667
# 4        북한산우이  4517.791667
# 5           삼양  2482.666667
# 6        삼양사거리  3125.541667
# 7   성신여대입구(돈암)  4274.708333
# 8         솔밭공원  3133.291667
# 9           솔샘  7153.333333
# 10         신설동  2627.458333
# 11          정릉  6151.166667
# 12          화계  4384.416667

# %%
uioff=pd.read_table("E:우이하차.txt")
uioff
# Out:
#           지하철역         승차인원
# 0     4.19민주묘지  4271.333333
# 1          가오리  5017.833333
# 2           보문  1955.583333
# 3       북한산보국문  7195.875000
# 4        북한산우이  4311.083333
# 5           삼양  2549.541667
# 6        삼양사거리  3052.583333
# 7   성신여대입구(돈암)  4861.500000
# 8         솔밭공원  2940.916667
# 9           솔샘  6524.291667
# 10         신설동  2565.375000
# 11          정릉  5314.958333
# 12          화계  4018.541667

# %%
subwaya5_ui[subwaya5_ui['지하철역']=='4.19민주묘지']
# Out:
#        호선명      지하철역  04시-05시 승차인원  05시-06시 승차인원  06시-07시 승차인원  07시-08시 승차인원  \
# 563  우이신설선  4.19민주묘지           4.0        1578.0        3409.0        8848.0
#
#      08시-09시 승차인원  09시-10시 승차인원  10시-11시 승차인원  11시-12시 승차인원  ...  \
# 563       10256.0        6433.0        5692.0        6064.0  ...
#
#      18시-19시 승차인원  19시-20시 승차인원  20시-21시 승차인원  21시-22시 승차인원  22시-23시 승차인원  \
# 563        7221.0        3573.0        3243.0        3398.0        1601.0
#
#      23시-24시 승차인원  00시-01시 승차인원  01시-02시 승차인원  02시-03시 승차인원  03시-04시 승차인원
# 563         379.0           4.0           0.0           0.0           0.0
#
# [1 rows x 26 columns]

# %%
subwaya5_419=subwaya5.query("지하철역=='4.19민주묘지'")
a419= pd.read_table("E:/419승차.txt")

a419["비율"]=(a419["인원수"]/1378209)*100
a419
# Out:
#                 인원수        비율
# 04시-05시 승차인원      4  0.000290
# 05시-06시 승차인원   1578  0.114496
# 06시-07시 승차인원   3409  0.247350
# 07시-08시 승차인원   8848  0.641993
# 08시-09시 승차인원  10256  0.744154
# 09시-10시 승차인원   6433  0.466765
# 10시-11시 승차인원   5692  0.413000
# 11시-12시 승차인원   6064  0.439991
# 12시-13시 승차인원   6870  0.498473
# 13시-14시 승차인원   7189  0.521619
# 14시-15시 승차인원   7426  0.538815
# 15시-16시 승차인원   7915  0.574296
# 16시-17시 승차인원   9208  0.668113
# 17시-18시 승차인원   8444  0.612679
# 18시-19시 승차인원   7221  0.523941
# 19시-20시 승차인원   3573  0.259250
# 20시-21시 승차인원   3243  0.235305
# 21시-22시 승차인원   3398  0.246552
# 22시-23시 승차인원   1601  0.116165
# 23시-24시 승차인원    379  0.027499
# 00시-01시 승차인원      4  0.000290
# 01시-02시 승차인원      0  0.000000
# 02시-03시 승차인원      0  0.000000
# 03시-04시 승차인원      0  0.000000

# %%
plt.rc('font', family='Malgun Gothic')
fig, ax = plt.subplots()
sns.set(rc = {'figure.figsize':(20,10)})

g=sns.barplot(data=uioff, x='지하철역', y='승차인원',color = '#D4C244')
ax=g
for p in ax.patches:
    ax.annotate("%.2f" % p.get_height(), (p.get_x() + p.get_width()/2., p.get_height() - 30),
       ha='center', va='center', fontsize=15, color='black', xytext=(0, 10),
       textcoords='offset points')


plt.title('2022년 5월 우이신설 역별 평균 하차 인원 수', fontsize=30)
ax.tick_params(axis='x', labelsize = 15, labelrotation = 75)
ax.legend(fontsize=20)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
ddf=pd.read_table("C:/Users/hyeee/Documents/카카오톡 받은 파일/ddf1.txt")

import matplotlib
plt.rc('font', family='Malgun Gothic')
matplotlib.rcParams['axes.unicode_minus'] =False
fig, ax = plt.subplots()
sns.set(rc = {'figure.figsize':(20,10)})

plt.plot(ddf['지하철역'], ddf['평균 승차 인원 수'], label='on')
plt.plot(ddf['지하철역'], ddf['평균 하차 인원 수'], label = 'off')

plt.title('2022년 5월 우이신설 평균 승하차 인원 수', fontsize=30)
ax.tick_params(axis='x', labelsize = 15, labelrotation = 75)
ax.legend(fontsize=20)

# %%
plt.rc('font', family='Malgun Gothic')
matplotlib.rcParams['axes.unicode_minus'] =False
fig, ax = plt.subplots()
sns.set(rc = {'figure.figsize':(20,10)})

plt.plot(dfu['시간'], dfu['평균 승차 인원 수'], label='on')
plt.plot(dfu['시간'], dfu['평균 하차 인원 수'], label = 'off')

plt.title('2022년 5월 우이신설 시간대별 평균 승하차 인원 수', fontsize=30)
ax.tick_params(axis='x', labelsize = 15, labelrotation = 75)
ax.legend(fontsize=20)

# %% [markdown]
# # 4호선, 우이신설선의 5월 승차 인원 히트맵

# %%
subwaya5_line4_mean = pd.DataFrame(subwaya5_line4.mean())
subwaya5_ui_mean = pd.DataFrame(subwaya5_ui.mean())
subwaya5_all_mean = pd.DataFrame(subwaya5_all.mean())
subwaya_all_line4_ui =pd.concat([subwaya5_all_mean,subwaya5_line4_mean,subwaya5_ui_mean ],axis=1,
                               ignore_index=True )
subwaya_all_line4_ui
# Out:
# C:\Users\hyeee\AppData\Local\Temp\ipykernel_13960\552634712.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   subwaya5_line4_mean = pd.DataFrame(subwaya5_line4.mean())
# C:\Users\hyeee\AppData\Local\Temp\ipykernel_13960\552634712.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   subwaya5_ui_mean = pd.DataFrame(subwaya5_ui.mean())
# C:\Users\hyeee\AppData\Local\Temp\ipykernel_13960\552634712.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
fig, ax = plt.subplots()

sns.set(rc = {'figure.figsize':(20,10)})
sns.heatmap(subwaya_all_line4_ui)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 전체지하철,4호선,우이신설선의 시간대별 평균 승차 인원

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
fig, ax = plt.subplots()

ax.set_title('전체지하철,4호선,우이신설 시간대별 평균 승차 인원', size = 22)
ax.tick_params(axis='x', labelsize = 8, labelrotation = 30)
sns.scatterplot(data=subwaya_all_line4_ui[3:19], s=300)
# Out:
# <AxesSubplot:title={'center':'전체지하철,4호선,우이신설 시간대별 평균 승차 인원'}>

# %% [markdown]
# # 4호선, 우이신설선의 시간대별 승차 인원 비율

# %%
asuyu= pd.read_table("E:/수유승차.txt")

asuyu["비율"]=(a419["인원수"]/14355117)*100
asuyu['비율']
# Out:
# 04시-05시 승차인원    0.000028
# 05시-06시 승차인원    0.010993
# 06시-07시 승차인원    0.023748
# 07시-08시 승차인원    0.061637
# 08시-09시 승차인원    0.071445
# 09시-10시 승차인원    0.044813
# 10시-11시 승차인원    0.039651
# 11시-12시 승차인원    0.042243
# 12시-13시 승차인원    0.047857
# 13시-14시 승차인원    0.050080
# 14시-15시 승차인원    0.051731
# 15시-16시 승차인원    0.055137
# 16시-17시 승차인원    0.064144
# 17시-18시 승차인원    0.058822
# 18시-19시 승차인원    0.050303
# 19시-20시 승차인원    0.024890
# 20시-21시 승차인원    0.022591
# 21시-22시 승차인원    0.023671
# 22시-23시 승차인원    0.011153
# 23시-24시 승차인원    0.002640
# 00시-01시 승차인원    0.000028
# 01시-02시 승차인원    0.000000
# 02시-03시 승차인원    0.000000
# 03시-04시 승차인원    0.000000
# Name: 비율, dtype: float64

# %%
a419suyu=pd.merge(a419,asuyu,how='outer',left_index=True, right_index=True)
print(a419suyu)
# Out:
#               인원수_x      비율_x   인원수_y      비율_y
# 04시-05시 승차인원      4  0.000290      67  0.000028
# 05시-06시 승차인원   1578  0.114496   22344  0.010993
# 06시-07시 승차인원   3409  0.247350   50257  0.023748
# 07시-08시 승차인원   8848  0.641993  118722  0.061637
# 08시-09시 승차인원  10256  0.744154  126579  0.071445
# 09시-10시 승차인원   6433  0.466765   80182  0.044813
# 10시-11시 승차인원   5692  0.413000   57625  0.039651
# 11시-12시 승차인원   6064  0.439991   52777  0.042243
# 12시-13시 승차인원   6870  0.498473   54652  0.047857
# 13시-14시 승차인원   7189  0.521619   52047  0.050080
# 14시-15시 승차인원   7426  0.538815   48846  0.051731
# 15시-16시 승차인원   7915  0.574296   48492  0.055137
# 16시-17시 승차인원   9208  0.668113   53019  0.064144
# 17시-18시 승차인원   8444  0.612679   57772  0.058822
# 18시-19시 승차인원   7221  0.523941   64823  0.050303
# 19시-20시 승차인원   3573  0.259250   37724  0.024890
# 20시-21시 승차인원   3243  0.235305   29607  0.022591
# 21시-22시 승차인원   3398  0.246552   26517  0.023671
# 22시-23시 승차인원   1601  0.116165   21684  0.011153
# ...

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot()

ax.plot(a419suyu.index, a419suyu.비율_x, marker='s', color='blue')
ax.plot(a419suyu.index, a419suyu.비율_y, marker='o', color='red')

plt.title('Plot with 1 Axis', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Value', fontsize=14)
plt.show()
